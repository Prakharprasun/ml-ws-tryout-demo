# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakharprasun/ml-ws-tryout-demo/blob/main/Pandas_21102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(10,90,(5,2)),columns=["a","b"])
df
# Out:
#     a   b
# 0  42  56
# 1  41  72
# 2  61  60
# 3  54  39
# 4  56  48

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df2=pd.read_csv("/content/sample_data/california_housing_test.csv")
df2
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df2.shape
# Out:
# (3000, 9)

# %%
df2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.head()
# Out:
#     a   b
# 0  42  56
# 1  41  72
# 2  61  60
# 3  54  39
# 4  56  48

# %%
df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df2.loc[0:10,"housing_median_age":"median_house_value"]
# Out:
#     housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                 27.0       3885.0           661.0      1537.0       606.0
# 1                 43.0       1510.0           310.0       809.0       277.0
# 2                 27.0       3589.0           507.0      1484.0       495.0
# 3                 28.0         67.0            15.0        49.0        11.0
# 4                 19.0       1241.0           244.0       850.0       237.0
# 5                 37.0       1018.0           213.0       663.0       204.0
# 6                 43.0       1009.0           225.0       604.0       218.0
# 7                 19.0       2310.0           471.0      1341.0       441.0
# 8                 15.0       3080.0           617.0      1446.0       599.0
# 9                 31.0       2402.0           632.0      2830.0       603.0
# 10                45.0        972.0           249.0      1288.0       261.0
#
#     median_income  median_house_value
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df2.iloc[0:11,1:3]
# Out:
#     latitude  housing_median_age
# 0      37.37                27.0
# 1      34.26                43.0
# 2      33.78                27.0
# 3      33.82                28.0
# 4      36.33                19.0
# 5      36.51                37.0
# 6      38.63                43.0
# 7      35.48                19.0
# 8      38.40                15.0
# 9      34.08                31.0
# 10     33.98                45.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['latitude'].plot(kind='hist', bins=20, title='latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['housing_median_age'].plot(kind='hist', bins=20, title='housing_median_age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
df2.housing_median_age.unique
# Out:
# <bound method Series.unique of 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64>

# %%
df2.housing_median_age.value_counts()
# Out:
# 52.0    173
# 35.0    118
# 36.0    115
# 16.0    107
# 34.0    102
# 17.0    100
# 32.0     91
# 37.0     88
# 26.0     88
# 25.0     86
# 33.0     85
# 15.0     77
# 19.0     76
# 18.0     76
# 30.0     76
# 24.0     75
# 29.0     75
# 27.0     74
# 38.0     64
# 20.0     63
# 21.0     61
# 22.0     60
# 28.0     58
# 14.0     57
# 31.0     57
# 41.0     56
# 43.0     56
# 39.0     55
# 23.0     53
# 44.0     51
# 45.0     51
# 42.0     51
# 40.0     43
# 46.0     41
# 11.0     41
# 12.0     41
# 13.0     41
# 5.0      39
# 48.0     34
# 10.0     30
# 4.0      28
# 9.0      27
# 6.0      25
# 8.0      25
# 47.0     22
# 49.0     21
# 7.0      20
# 50.0     16
# 3.0      12
# 51.0     11
# 2.0       6
# 1.0       2
# Name: housing_median_age, dtype: int64

# %%
df2.housing_median_age.unique()
# Out:
# array([27., 43., 28., 19., 37., 15., 31., 45., 36., 16., 42., 26., 35.,
#        40., 47., 13., 52., 32., 30., 14., 34., 17.,  5., 38., 33., 11.,
#        48.,  4., 24.,  6., 21., 39., 10., 44., 18., 12., 22., 29., 46.,
#        50., 20., 49., 25., 23., 41.,  8.,  3.,  7.,  9.,  2., 51.,  1.])
